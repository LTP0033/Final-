# %% [markdown]
# # !pip install ultralytics --upgrade -q
# from ultralytics import YOLO

# %%
from ultralytics import YOLO

epochs = 200
batch_size = 16
lr = 0.001
imgsz = 640
optimizer = 'Adam'
data = '/kaggle/input/yellow-sticky-dataset-zip/data.yaml'

model = YOLO("yolo11n.pt")
results = model.train(data=data, batch=batch_size, epochs=epochs, imgsz=imgsz, optimizer=optimizer)
# Out:
# Ultralytics 8.3.146 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
