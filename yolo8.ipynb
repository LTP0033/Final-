# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/yellow-sticky-dataset-zip/README.dataset.txt
# /kaggle/input/yellow-sticky-dataset-zip/README.roboflow.txt
# /kaggle/input/yellow-sticky-dataset-zip/data.yaml
# /kaggle/input/yellow-sticky-dataset-zip/valid/labels/1254_jpg.rf.420ec3f361e8cc5ada5c6ade3bb9aa4a.txt
# /kaggle/input/yellow-sticky-dataset-zip/valid/labels/1095_jpg.rf.28006157cfe4bcf20c9edf692223d53a.txt
# /kaggle/input/yellow-sticky-dataset-zip/valid/labels/1032_jpg.rf.7032ebd2ca69aab4cda6578f9668ddd0.txt
# /kaggle/input/yellow-sticky-dataset-zip/valid/labels/1240_jpg.rf.b4e3d45ba7f13c02927e3f6d1ae9e666.txt
# /kaggle/input/yellow-sticky-dataset-zip/valid/labels/1038_jpg.rf.defff1d33ca2a3b4928ebe9501e2a1db.txt
# /kaggle/input/yellow-sticky-dataset-zip/valid/labels/1013_jpg.rf.837d51969c2d3bb5df65b3d44e7f1627.txt
# /kaggle/input/yellow-sticky-dataset-zip/valid/labels/1253_jpg.rf.fd9700515f6f0befa3e2749626569911.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.7 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.8 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
# ...

# %%
from ultralytics import YOLO
# Load a model
data_path = '/kaggle/input/yellow-sticky-dataset-zip/data.yaml'
#'đường dẫn đến file data.yaml trong dataset'
model = YOLO("yolov8n.pt")  # build a new model from YAML

# Train the model
results = model.train(data=data_path, epochs=200, imgsz=640, device = 0)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 22.3MB/s]
# Ultralytics 8.3.146 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
